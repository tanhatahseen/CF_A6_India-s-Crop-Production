# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
df = pd.read_csv('/content/India_crops_preprocessed_categorized_wtout_outliers.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                       State  District      Crop  Crop_Year  \
# 0           0  Andaman and Nicobar Island  Nicobars  Arecanut       2007
# 1           1  Andaman and Nicobar Island  Nicobars  Arecanut       2007
# 2           2  Andaman and Nicobar Island  Nicobars  Arecanut       2008
# 3           3  Andaman and Nicobar Island  Nicobars  Arecanut       2008
# 4           4  Andaman and Nicobar Island  Nicobars  Arecanut       2009
#
#         Season    Area  Production  Yield Area_Category Production_Category  \
# 0  Kharif       2439.6      3415.0   1.40    Large Land  Regular Production
# 1  Rabi         1626.4      2277.0   1.40    Large Land  Regular Production
# 2  Autumn       4147.0      3060.0   0.74    Large Land  Regular Production
# 3  Summer       4147.0      2660.0   0.64    Large Land  Regular Production
# 4  Autumn       4153.0      3120.0   0.75    Large Land  Regular Production
#
#   Yield_Category
# 0  Regular Yield
# 1  Regular Yield
# ...

# %%
data_to_plot = df[['Area','Production','Yield']]

# %%
data_to_plot.head()
# Out:
#      Area  Production  Yield
# 0  2439.6      3415.0   1.40
# 1  1626.4      2277.0   1.40
# 2  4147.0      3060.0   0.74
# 3  4147.0      2660.0   0.64
# 4  4153.0      3120.0   0.75

# %%
# Create a correlation matrix using pandas

data_to_plot.corr()
# Out:
#                Area  Production     Yield
# Area        1.00000    0.763990 -0.048650
# Production  0.76399    1.000000  0.283411
# Yield      -0.04865    0.283411  1.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(data_to_plot.corr())
plt.show()

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(data_to_plot.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %%
# Create a scatterplot for the "Area" and "Production" columns in seaborn

sns.lmplot(x = 'Area', y = 'Production', data = data_to_plot)

# %%
# Create a scatterplot for the "Area" and "Yield" columns in seaborn

sns.lmplot(x = 'Area', y = 'Yield', data = data_to_plot)

# %%
# Create a scatterplot for the "Production" and "Yield" columns in seaborn

sns.lmplot(x = 'Production', y = 'Yield', data = data_to_plot)

# %%
# Create a pair plot 

g = sns.pairplot(data_to_plot)

# %%
# Create a categorical plot in seaborn using the area categories created above

sns.set(style="ticks")
g = sns.catplot(x="Area", y="Production", hue="Area_Category", data= df, palette = "bright")
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:118: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Creating scatterplot for production in different seasons

# %%
df['Season'].str.strip()
# Out:
# 0         Kharif
# 1           Rabi
# 2         Autumn
# 3         Summer
# 4         Autumn
#            ...
# 233796      Rabi
# 233797      Rabi
# 233798      Rabi
# 233799      Rabi
# 233800      Rabi
# Name: Season, Length: 233801, dtype: object

# %%
df.head()

# %%
df['Season'].astype(str)

# %%
sns.lmplot(x = 'Area', y = 'Production', data = df, hue = "Season", palette = "bright")

# %% [markdown]
# *   **Months in Kharif:**  starts in June and ends in October (rainy season)
# *   **Months in Rabi:** crops are sown in mid-November and harvested in April/May
# *   **Months in Summer:** March to May
# *   **Months in Winter:** December to February
# *   **Months in Autumn:** October and November

# %% [markdown]
# **Crops Season in India:**

# %% [markdown]
# 1. Kharif Crops
#
# *  July – October (crops are sown usually at the beginning of the first monsoon rains).
# *  Harvest – September to October.
# *  A.k.a Monsoon Crops.
# *  Such crops require a lot of water.
# *  Example: rice, sorghum, maize, tea, rubber, coffee, guar, Sesame, cereals such as Arhar Dhal, pearl millet, soybeans, cotton, oilseeds, etc.

# %% [markdown]
# 2. Rabi Crops
#
# *   Sowing between October and November (preferably after the monsoon rains)
# *   Harvest – February to April
# *   A.k.a Winter Season Crops
# *   Need cold weather for growth
# *   Need less water
# *   Example: wheat, oats, barley, pulses, cereals, oilseeds, linseed, etc.

# %% [markdown]
# 3. Zaid Crops
#
# *   Zaid crops are also called summer crops
# *   Sown and harvested between March and June (between Kharif and Rabi)
# *   Requires warm & dry weather for growth and a longer day-length for flowering
# *   Example:
# Pumpkin,
# Cucumber,
# Bitter Gourd.
